# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
from google.colab import userdata
token = userdata.get('github')
# !git clone https://iamcmj:{token}@github.com/iamcmj/PAZULE.git
# Out:
# Cloning into 'PAZULE'...
# remote: Enumerating objects: 885, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 885 (delta 29), reused 39 (delta 12), pack-reused 812 (from 2)
# Receiving objects: 100% (885/885), 179.53 MiB | 39.99 MiB/s, done.
# Resolving deltas: 100% (320/320), done.

# %%
# %cd PAZULE
# Out:
# /content/PAZULE

# %%
# !ls -la
# Out:
# total 108
# drwxr-xr-x 14 root root 4096 Nov 24 10:41 .
# drwxr-xr-x  1 root root 4096 Nov 24 10:40 ..
# -rw-r--r--  1 root root 6615 Nov 24 10:41 answer_manager.py
# drwxr-xr-x  3 root root 4096 Nov 24 10:41 blip
# drwxr-xr-x  6 root root 4096 Nov 24 10:41 blip_standalone_game
# drwxr-xr-x  3 root root 4096 Nov 24 10:41 clip
# drwxr-xr-x  2 root root 4096 Nov 24 10:41 config
# -rw-r--r--  1 root root 1240 Nov 24 10:41 coupon_manager.py
# drwxr-xr-x 18 root root 4096 Nov 24 10:41 data
# -rw-r--r--  1 root root  182 Nov 24 10:41 .env
# drwxr-xr-x  4 root root 4096 Nov 24 10:41 front
# drwxr-xr-x  8 root root 4096 Nov 24 10:41 .git
# -rw-r--r--  1 root root  311 Nov 24 10:41 .gitignore
# -rw-r--r--  1 root root 2998 Nov 24 10:41 main.py
# drwxr-xr-x  4 root root 4096 Nov 24 10:41 metadata
# -rw-r--r--  1 root root 2265 Nov 24 10:41 mission_manager.py
# drwxr-xr-x  2 root root 4096 Nov 24 10:41 models
# drwxr-xr-x  2 root root 4096 Nov 24 10:41 __pycache__
# ...

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 68.1 MB/s eta 0:00:00
# ...

# %%
# %cd front/
# Out:
# /content/PAZULE/front

# %%
# !npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# added 153 packages, and audited 154 packages in 3s
# ⠼
# ⠼32 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# 1 moderate severity vulnerability
#
# To address all issues, run:
#   npm audit fix
#
# Run `npm audit` for details.
# ⠼

# %%
# vite.config.js를 다시 덮어씁니다 (Proxy 설정 추가)
vite_config_code = """
import { defineConfig } from 'vite'
import react from '@vitejs/plugin-react'

// https://vite.dev/config/
export default defineConfig({
  plugins: [react()],
  server: {
    host: '0.0.0.0',
    allowedHosts: true,
    proxy: {
      // ✅ '/api'로 시작하는 요청은 무조건 백엔드(8000번)로 토스해라!
      '/api': {
        target: 'http://127.0.0.1:8000',
        changeOrigin: true,
        secure: false,
      },
      // ✅ '/get-today-hint' 요청도 백엔드로 토스!
      '/get-today-hint': {
        target: 'http://127.0.0.1:8000',
        changeOrigin: true,
        secure: false,
      }
    }
  }
})
"""

with open('vite.config.js', 'w') as f:
    f.write(vite_config_code)

print("✅ vite.config.js 프록시 설정 완료! 서버를 재시작하세요.")
# Out:
# ✅ vite.config.js 프록시 설정 완료! 서버를 재시작하세요.

# %%
from google.colab.output import eval_js

print(eval_js("google.colab.kernel.proxyPort(5173)"))
# Out:
# https://5173-gpu-l4-s-1b3hv4f1t978-c.us-west4-0.prod.colab.dev

# %%
token2 = userdata.get('openai')

# %%
# !npm run dev -- --host
# Out:
# > frontend@0.0.0 dev
# > vite --host
#
#
#
#   VITE v7.2.2  ready in 209 ms
#
#   ➜  Local:   http://localhost:5173/
#   ➜  Network: http://172.28.0.12:5173/
#   ➜  press h + enter to show help

# %%
from google.colab import output
output.serve_kernel_port_as_window(3000)

# %%
# %cd front
# Out:
# /content/PAZULE/front
