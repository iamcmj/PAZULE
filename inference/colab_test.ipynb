# %%
from google.colab import userdata
token = userdata.get('github')
# !git clone https://iamcmj:{token}@github.com/iamcmj/group5_project.git
# !ls -la group5_project/
# Out:
# Cloning into 'group5_project'...
# remote: Enumerating objects: 275, done.
# remote: Total 275 (delta 0), reused 0 (delta 0), pack-reused 275 (from 1)
# Receiving objects: 100% (275/275), 110.65 MiB | 36.46 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
# total 40
# drwxr-xr-x 8 root root 4096 Nov  3 06:41 .
# drwxr-xr-x 1 root root 4096 Nov  3 06:41 ..
# drwxr-xr-x 3 root root 4096 Nov  3 06:41 blip
# drwxr-xr-x 2 root root 4096 Nov  3 06:41 clip
# drwxr-xr-x 8 root root 4096 Nov  3 06:41 .git
# -rw-r--r-- 1 root root   17 Nov  3 06:41 .gitignore
# drwxr-xr-x 2 root root 4096 Nov  3 06:41 inference
# drwxr-xr-x 3 root root 4096 Nov  3 06:41 metadata
# drwxr-xr-x 8 root root 4096 Nov  3 06:41 pytorch-template
# -rw-r--r-- 1 root root  128 Nov  3 06:41 README.md

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git config --global user.name iamcmj

# %%
# !git config --global user.email alexcho0913@gmail.com

# %%
# %cd group5_project/inference
# Out:
# /content/group5_project/inference

# %%
# !ls -la
# Out:
# total 328
# drwxr-xr-x 2 root root   4096 Nov  3 06:41 .
# drwxr-xr-x 8 root root   4096 Nov  3 06:41 ..
# -rw-r--r-- 1 root root 326291 Nov  3 06:41 test.ipynb

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
import shutil
import os

source = "/content/drive/MyDrive/GitHub_test/colab_test.ipynb"
destination = "/content/group5_project/clip/"

shutil.copy(source, destination)
print(f"파일 복사 완료: {destination}")
# Out:
# 파일 복사 완료: /content/group5_project/clip/

# %%
# %cd /content/group5_project/clip
# !ls -la
# !git add colab_test.ipynb
# !git commit -m "colab github test"
# !git push
# Out:
# /content/group5_project/clip
# total 45856
# drwxr-xr-x 2 root root     4096 Nov  3 06:26 .
# drwxr-xr-x 8 root root     4096 Nov  3 06:07 ..
# -rw-r--r-- 1 root root   209133 Nov  3 06:07 CLIP2.ipynb
# -rw-r--r-- 1 root root 44101776 Nov  3 06:07 CLIP3.ipynb
# -rw-r--r-- 1 root root   161664 Nov  3 06:07 CLIP.ipynb
# -rw-r--r-- 1 root root     2815 Nov  3 06:07 CLIP.md
# -rw-r--r-- 1 root root  2447913 Nov  3 06:07 clip_perf_test.ipynb
# -rw------- 1 root root     8797 Nov  3 06:26 colab_test.ipynb
# [main 5b5cdca] colab github test
#  1 file changed, 1 insertion(+)
#  create mode 100644 clip/colab_test.ipynb
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/iamcmj/group5_project.git/': The requested URL returned error: 403

# %%
# !git remote -v
# Out:
# origin	https://iamcmj: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@github.com/iamcmj/group5_project.git (fetch)
# origin	https://iamcmj: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@github.com/iamcmj/group5_project.git (push)
